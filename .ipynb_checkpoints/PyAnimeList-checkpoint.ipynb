# %% [markdown]
# PyAnimeList by Patrick Tjahjadi
#
# Program to retrieve Anime/Donghua data from MyAnimeList, including score, year, genre, etc.
#
# Allows users to filter Anime/Donghua based on these attributes with a sorting feature.
#
# Search for your favourite Anime/Donghua or simply look for recommendation with the filtering and sorting feature!

# %%
# Imported Libraries
from jikanpy import Jikan
import pandas as pd
import time
from IPython.display import clear_output
import dill

# %%
# Set up data for anime from 2000 to 2020 for retrieval using the Jikan API

jikan = Jikan()

years = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
         2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
seasons = ['winter', 'spring', 'summer', 'fall']

myanimelist = []

# %%
# Retrieve anime data through Jikan
# Time delay of 7 seconds per year for API rate limiting
for year in years:
    for season in seasons:
        myanimelist.append(jikan.season(year = year, season = season))
    time.sleep(7)

# %%
# Store the Python data into bite streams for faster future processing
dill.dump_session('my_anime_list.db')

# We can load this later instead of retrieving data again
#dill.load_session('my_anime_list.db')

# %%
# Collect all necessary attributes: Title, Score, Members, Genre, Producers, Year, Season and Synopsis
animedata = []
for animeseason in myanimelist:
    for show in animeseason['anime']:
        animedata.append([show['title'], show['score'], show['members'], ', '.join(genre['name'] for genre in show['genres']), 
                        ', '.join(producer['name'] for producer in show['producers']), animeseason["season_year"],
                        animeseason["season_name"], show['synopsis']])

# %%
# Create a dataframe to store Anime data and remove duplicate entries
anime_df = pd.DataFrame(animedata, columns = ["Title", "Score", "Members", "Genre", "Producers", "Year", "Season", "Synopsis",])
anime_df.index.name = "Anime ID"
anime_df.drop_duplicates(subset="Title", keep = 'first', inplace = True)

# %%
# Function to retrieve anime based on filtering and sorting input
def get_my_anime(output_anime_df):
    list_of_queries = []
    list_of_sort = ["None"]
    while (1):
        print("Your queries: \n"+", ".join(list_of_queries))
        method = input("Search anime based on (Title, Score, Members, Genre, Year, Season or Synopsis)? Otherwise, input 0.\n")
        if (method == "0"):
            break
        elif (method.lower() in ["title", "score", "members", "genre", "year", "season", "synopsis"]):
            output_anime_df = query_my_anime(output_anime_df, method, list_of_queries)
    output_anime_df = sort_my_anime(output_anime_df, list_of_queries, list_of_sort)
    clear_output(wait=True)
    print("Your queries: \n"+", ".join(list_of_queries))
    print("Your sorting method: \n"+list_of_sort[0])
    return output_anime_df

# Function to filter anime based on attributes
def query_my_anime(interim_df, method, list_of_queries):
    if (method.lower() in ["title", "genre", "producers", "season", "synopsis"]):
        query_content = input("Search by anime "+method.capitalize()+":\n")
        interim_df = interim_df.query('{}.str.contains("{}")'.format(method.capitalize(), query_content), engine = 'python')
        list_of_queries.append("{}: {}".format(method.capitalize(), query_content))
    elif (method.lower() in ["score", "members", "year"]):
        operator = input("Find anime "+method.capitalize()+" less than, equal to, greater than, or range (L = Less, E = Equal, G = Greater, R = Range)?\n")
        if (operator.lower() in ["g", "greater", "greater than"]):
            value = input("Greater than which "+method.capitalize()+ "?\n")
            interim_df = interim_df.query('{} > {}'.format(method.capitalize(), value))
            list_of_queries.append("{} > {}".format(method.capitalize(), value))
        elif (operator.lower() in ["e", "equal", "equal to"]):
            value = input("Equal to which "+method.capitalize()+ "?\n")
            interim_df = interim_df.query('{} == {}'.format(method.capitalize(), value))
            list_of_queries.append("{} = {}".format(method.capitalize(), value))
        elif (operator.lower() in ["l", "less", "less than"]):
            value = input("Less than which "+method.capitalize()+ "?\n")
            interim_df = interim_df.query('{} < {}'.format(method.capitalize(), value))
            list_of_queries.append("{} < {}".format(method.capitalize(), value))
        elif (operator.lower() in ["r", "range"]):
            value_low = input("Between which values inclusive? Set lower limit:\n")
            value_high = input("Between which values inclusive? Set upper limit:\n")
            interim_df = interim_df.query('{} > {} and {} < {}'.format(method.capitalize(), value_low, method.capitalize(), value_high))
            list_of_queries.append("{} <= {} <= {}".format(value_low, method.capitalize(), value_high))
    clear_output(wait=True)        
    return interim_df

# Functions to sort the order of anime to be output
def sort_my_anime(interim_df, list_of_queries, list_of_sort):
    clear_output(wait = True)
    print("Your queries: \n"+", ".join(list_of_queries))
    while (1):
        sort_attribute = input("Any sorting method (Title, Score, Members, Genre, Year, Season or Synopsis)? Otherwise, input 0.\n")
        if (sort_attribute.lower() in ["title", "score", "members", "genre", "year", "season", "synopsis"]):
            while (1):
                sort_method = input("Ascending or Descending (A = Ascending, D = Descending)?")
                if (sort_method.lower() == "a"):
                    interim_df = interim_df.sort_values(sort_attribute.capitalize(), ascending = True)
                    list_of_sort[0] = sort_attribute.capitalize()+": Ascending"
                    return interim_df
                elif (sort_method.lower() == "d"):
                    interim_df = interim_df.sort_values(sort_attribute.capitalize(), ascending = False)
                    list_of_sort[0] = sort_attribute.capitalize()+": Descending"
                    return interim_df
        elif (sort_attribute == "0"):
            return interim_df

# %%
query_df = get_my_anime(anime_df)
query_df
# Out:
# Your queries:
# Score > 7
# Your sorting method:
# None
#                                                       Title  Score  Members  \
# Anime ID
# 0                                    Boogiepop wa Warawanai   7.17    87262
# 2                                      Ojamajo Doremi Sharp   7.33    14770
# 4                                  Kazemakase Tsukikage Ran   7.12    12596
# 5                                       Popee the Performer   7.13     5686
# 11                                                One Piece   8.49  1176555
# 12                                    Great Teacher Onizuka   8.70   540653
# 13                                                  Pokemon   7.35   426234
# 14                                          Hunter x Hunter   8.43   372315
# 15                                        Cardcaptor Sakura   8.16   318133
# 16                                        Digimon Adventure   7.80   308099
# 17                                          Detective Conan   8.17   231224
# 18                      Heppoko Jikken Animation Excel♥Saga   7.51    91037
# 19                                                The Big O   7.53    72618
# 20                                              Blue Gender   7.06    63161
# 21                                         Crayon Shin-chan   7.69    52796
# 22                                                  Medarot   7.07    46123
# 23                                                    Zoids   7.39    40111
# 24                                          Mugen no Ryvius   7.49    35551
# 26                                            Turn A Gundam   7.70    33911
# 27                                          Doraemon (1979)   7.69    33632
# 29                             Kindaichi Shounen no Jikenbo   7.99    20011
# 32         Kochira Katsushikaku Kameari Kouenmae Hashutsujo   7.75    11098
# 33                                            Kaikan Phrase   7.41    10986
# 34                                               Jibaku-kun   7.40    10242
# 35                            Karakurizoushi Ayatsuri Sakon   7.40     9333
# 36                           Chikyuu Bouei Kigyou Dai-Guard   7.13     7414
# 38                                         Cyborg Kuro-chan   7.11     5927
# 40                                         Nintama Rantarou   7.07     4860
# 44                                 Chibi Maruko-chan (1995)   7.19     2792
# 45                                               Kyoro-chan   7.22     2039
# ...                                                     ...    ...      ...
# 16370     Ore wo Suki nano wa Omae dake ka yo: Oretachi ...   7.70    61983
# 16373                               Isekai Harem Monogatari   7.37     3665
# 16383                               Violet Evergarden Movie   8.46   140680
# 16384     Fate/stay night Movie: Heaven's Feel - III. Sp...   8.77    95141
# 16385                                           Given Movie   7.30    44733
# 16386                         Date A Bullet: Dead or Bullet   7.44    44296
# 16387                         Shingeki no Kyojin: Chronicle   7.27    37227
# 16409                                   Jujutsu Kaisen (TV)   8.19   198174
# 16410     Dungeon ni Deai wo Motomeru no wa Machigatteir...   7.70   185278
# 16411                      Haikyuu!!: To the Top 2nd Season   8.63   178896
# 16412            Mahouka Koukou no Rettousei: Raihousha-hen   7.81   126371
# 16413                                       Tonikaku Kawaii   7.78   115868
# 16414                         Higurashi no Naku Koro ni Gou   7.45   105486
# 16415                                      Majo no Tabitabi   7.63    92452
# 16417                                  Kamisama ni Natta Hi   7.63    82371
# 16418     Kimi to Boku no Saigo no Senjou, Aruiwa Sekai ...   7.04    79188
# 16420                                         Akudama Drive   7.72    66048
# 16421                                   Yuukoku no Moriarty   7.63    55348
# 16422                                   Adachi to Shimamura   7.45    54779
# 16423                                         Munou na Nana   7.30    54642
# 16424              Hanyou no Yashahime: Sengoku Otogizoushi   7.52    49804
# 16426                               Golden Kamuy 3rd Season   8.25    41841
# 16428                                    Maoujou de Oyasumi   7.57    38290
# 16433     Love Live! Nijigasaki Gakuen School Idol Douko...   7.97    25482
# 16434                 Dragon Quest: Dai no Daibouken (2020)   7.21    23676
# 16435                     Gochuumon wa Usagi Desu ka? Bloom   7.90    22847
# 16443                        Strike Witches: Road to Berlin   7.02    10851
# 16445                               Osomatsu-san 3rd Season   7.65     7737
# 16568              Kimetsu no Yaiba Movie: Mugen Ressha-hen   8.18   229742
# 16569                                        Burn the Witch   7.25    82517
#
#                                                       Genre  \
# Anime ID
# 0         Psychological, Supernatural, Dementia, Mystery...
# 2                                     Comedy, Magic, Shoujo
# 4         Adventure, Comedy, Historical, Martial Arts, S...
# 5                                          Comedy, Dementia
# 11        Action, Adventure, Comedy, Super Power, Drama,...
# 12            Slice of Life, Comedy, Drama, School, Shounen
# 13                 Action, Adventure, Comedy, Kids, Fantasy
# 14         Action, Adventure, Super Power, Fantasy, Shounen
# 15        Adventure, Comedy, Drama, Magic, Romance, Fant...
# 16                 Action, Adventure, Comedy, Fantasy, Kids
# 17              Adventure, Mystery, Comedy, Police, Shounen
# 18                          Comedy, Parody, Sci-Fi, Shounen
# 19            Action, Sci-Fi, Mystery, Psychological, Mecha
# 20        Adventure, Romance, Mecha, Military, Sci-Fi, H...
# 21             Slice of Life, Comedy, Ecchi, School, Seinen
# 22                       Adventure, Comedy, Sci-Fi, Shounen
# 23                 Action, Adventure, Comedy, Mecha, Sci-Fi
# 24        Drama, Mecha, Military, Psychological, Sci-Fi,...
# 26        Action, Military, Sci-Fi, Adventure, Space, Dr...
# 27        Adventure, Comedy, Fantasy, Kids, Sci-Fi, Shounen
# 29                                         Mystery, Shounen
# 32                            Slice of Life, Comedy, Police
# 33                            Drama, Music, Romance, Shoujo
# 34                               Adventure, Fantasy, Comedy
# 35                       Mystery, Horror, Thriller, Shounen
# 36               Military, Sci-Fi, Adventure, Comedy, Mecha
# 38                                           Comedy, Sci-Fi
# 40                                             Comedy, Kids
# 44                      Slice of Life, Comedy, Kids, School
# 45                               Adventure, Comedy, Fantasy
# ...                                                     ...
# 16370                               Comedy, Romance, School
# 16373                                Harem, Hentai, Fantasy
# 16383                         Slice of Life, Drama, Fantasy
# 16384                  Action, Supernatural, Magic, Fantasy
# 16385      Music, Slice of Life, Drama, Romance, Shounen Ai
# 16386                                                Sci-Fi
# 16387     Action, Military, Mystery, Super Power, Drama,...
# 16409     Action, Horror, Demons, Supernatural, School, ...
# 16410           Action, Adventure, Comedy, Romance, Fantasy
# 16411                Comedy, Sports, Drama, School, Shounen
# 16412     Action, Sci-Fi, Supernatural, Magic, Romance, ...
# 16413                              Comedy, Romance, Shounen
# 16414     Dementia, Horror, Mystery, Psychological, Supe...
# 16415                                    Adventure, Fantasy
# 16417                                        Drama, Fantasy
# 16418                    Action, Military, Romance, Fantasy
# 16420                                        Action, Sci-Fi
# 16421           Mystery, Historical, Psychological, Shounen
# 16422             Slice of Life, Romance, School, Shoujo Ai
# 16423     Super Power, Psychological, Supernatural, Thri...
# 16424     Action, Adventure, Comedy, Historical, Demons,...
# 16426                 Action, Adventure, Historical, Seinen
# 16428     Slice of Life, Comedy, Supernatural, Magic, Fa...
# 16433                          Music, Slice of Life, School
# 16434                   Action, Adventure, Fantasy, Shounen
# 16435                                 Slice of Life, Comedy
# 16443                Action, Military, Sci-Fi, Magic, Ecchi
# 16445                                        Comedy, Parody
# 16568     Action, Historical, Demons, Supernatural, Shounen
# 16569                       Action, Magic, Fantasy, Shounen
#
#                              Producers  Year  Season  \
# Anime ID
# 0                             Madhouse  2000  Winter
# 2                       Toei Animation  2000  Winter
# 4                             Madhouse  2000  Winter
# 5                     Nippon Animation  2000  Winter
# 11                      Toei Animation  2000  Winter
# 12                      Studio Pierrot  2000  Winter
# 13                                 OLM  2000  Winter
# 14                    Nippon Animation  2000  Winter
# 15                            Madhouse  2000  Winter
# 16                      Toei Animation  2000  Winter
# 17                   TMS Entertainment  2000  Winter
# 18                           J.C.Staff  2000  Winter
# 19                             Sunrise  2000  Winter
# 20                                 AIC  2000  Winter
# 21                   Shin-Ei Animation  2000  Winter
# 22                           Bee Train  2000  Winter
# 23                               Xebec  2000  Winter
# 24                             Sunrise  2000  Winter
# 26        Nakamura Production, Sunrise  2000  Winter
# 27                   Shin-Ei Animation  2000  Winter
# 29                      Toei Animation  2000  Winter
# 32                              Gallop  2000  Winter
# 33                       Studio Hibari  2000  Winter
# 34                          Trans Arts  2000  Winter
# 35                   TMS Entertainment  2000  Winter
# 36                               Xebec  2000  Winter
# 38                        Studio Bogey  2000  Winter
# 40                             Ajia-Do  2000  Winter
# 44                    Nippon Animation  2000  Winter
# 45                           Group TAC  2000  Winter
# ...                                ...   ...     ...
# 16370                          Connect  2020  Summer
# 16373                                   2020  Summer
# 16383                  Kyoto Animation  2020  Summer
# 16384                         ufotable  2020  Summer
# 16385                           Lerche  2020  Summer
# 16386                        GEEK TOYS  2020  Summer
# 16387                                   2020  Summer
# 16409                            MAPPA  2020    Fall
# 16410                        J.C.Staff  2020    Fall
# 16411                   Production I.G  2020    Fall
# 16412                             8bit  2020    Fall
# 16413                       Seven Arcs  2020    Fall
# 16414                         Passione  2020    Fall
# 16415                              C2C  2020    Fall
# 16417                       P.A. Works  2020    Fall
# 16418                     Silver Link.  2020    Fall
# 16420                   Studio Pierrot  2020    Fall
# 16421                   Production I.G  2020    Fall
# 16422               Tezuka Productions  2020    Fall
# 16423                           Bridge  2020    Fall
# 16424                          Sunrise  2020    Fall
# 16426                      Geno Studio  2020    Fall
# 16428                        Doga Kobo  2020    Fall
# 16433                          Sunrise  2020    Fall
# 16434                   Toei Animation  2020    Fall
# 16435                  Encourage Films  2020    Fall
# 16443                 David Production  2020    Fall
# 16445                   Studio Pierrot  2020    Fall
# 16568                         ufotable  2020    Fall
# 16569                  Studio Colorido  2020    Fall
#
#                                                    Synopsis
# Anime ID
# 0         Five years ago, a string of grisly murders sho...
# 2         At the end of the first season, Doremi and her...
# 4         In the Edo or Tokugawa period (1600–1868), Ran...
# 5         Popee the Performer deals with a circus that o...
# 11        Gol D. Roger was known as the "Pirate King," t...
# 12        Twenty-two-year-old Eikichi Onizuka—ex-biker g...
# 13        Pokemon are peculiar creatures with a vast arr...
# 14        Hunters are specialized in a wide variety of f...
# 15        Sakura Kinomoto is your garden-variety ten-yea...
# 16        When a group of seven children go to summer ca...
# 17        Shinichi Kudou, a high school student of astou...
# 18        It's hard to take over the world, and the enig...
# 19        Paradigm City, a city of amnesia and a place o...
# 20        Blue Gender takes place in the not too distant...
# 21        Just because an anime features a young protago...
# 22        Medabots—powerful robots granted artificial in...
# 23        Zoids are beast-like fighting machines used in...
# 24         The year is AD 2225. Kouji Aiba and Aoi House...
# 26        It is the Correct Century, two millennia after...
# 27        Nobita Nobi is a normal fourth grade student. ...
# 29        Hajime Kindaichi's unorganized appearance and ...
# 32        Ryoutsu, being an underpaid policeman, is alwa...
# 33        After the break up of their old band, guitaris...
# 34        Bucky, the protagonist of the history, is a no...
# 35        The dark-haired bishounen is Sakon Tachibana, ...
# 36        Thirteen years after their sudden disappearanc...
# 38        Kuro is just an ordinary cat who only wants to...
# 40        Rantarou, Shinbei and Kirimaru are ninja appre...
# 44        Momoko Sakura is an elementary school student ...
# 45        While exploring ruins on Angel Island, a docto...
# ...                                                     ...
# 16370     The original video anime episode will serve as...
# 16373                                    (No synopsis yet.)
# 16383     An original sequel to the TV anime which aired...
# 16384     Final of three movies in an adaption of the th...
# 16385     While the TV anime focused on the band given's...
# 16386     This is the story of Tokisaki Kurumi that shou...
# 16387     The compilation film will recap the anime's 59...
# 16409     In a world where demons feed on unsuspecting h...
# 16410     Third season of Dungeon ni Deai wo Motomeru no...
# 16411                 Second half of Haikyuu!!: To the Top.
# 16412     Shiba Miyuki's classmate Kitayama Shizuku is o...
# 16413     Having grown up ridiculed for his bizarre name...
# 16414     New kid Keiichi Maebara is settling into his n...
# 16415     Once upon a time, there was a witch named Elai...
# 16417     At the end of the last summer vacation of high...
# 16418     A great war has raged for years between the sc...
# 16420     Long ago, a war broke out in Japan that pitted...
# 16421     In the late 19th century, the British Empire h...
# 16422     The second floor of the gym―this was where we ...
# 16423     It is the year 20XX. Earth was assaulted by mo...
# 16424     The daughters of Sesshoumaru and Inuyasha set ...
# 16426                         Third season of Golden Kamuy.
# 16428     Sshhh! Princess Syalis is trying to get a good...
# 16433     Nijigasaki High School is located in Odaiba, T...
# 16434     A long time ago, there was a valiant swordsman...
# 16435           Third season of Gochuumon wa Usagi Desu ka.
# 16443                                    (No synopsis yet.)
# 16445                         Third season of Osomatsu-san.
# 16568     Tanjirou Kamado and his friends from the Demon...
# 16569     Historically, 72% of all the deaths in London ...
#
# [3125 rows x 8 columns]
